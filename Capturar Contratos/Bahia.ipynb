# %%
from tkinter import *

from tkinter.ttk import *
import re
from textblob import TextBlob
from tqdm.auto import tqdm
from tkinter import Label
import time
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import os
from pathlib import Path

# %%
def tentativa(numero_de_tentativas, css_code_selector,driver):
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual <= numero_de_tentativas:
        
        #tenta clicar no botão
        try:
            driver.find_element_by_css_selector(css_code_selector).click()
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
    
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
        
    #caso contrário, informa que passou no teste
    else:
        print("Pass tentativa!")
    
    return

# %%
def acha_lista_de_links(numero_de_tentativas, css_code_selector, driver):
    
    lista_links = []
    lista_nomes = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    cont = 1
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
            cont1=1
            
            
            while cont <=3:
                a = True
                cont2=1
                while a==True:
                    try:

                        elementos = driver.find_element_by_xpath(f'/html/body/div[1]/div[3]/div/div/div[{cont1}]/table/tbody/tr[1]/td/p/a')


                        link = elementos.get_attribute("href")
                        #elementos = driver.find_element_by_xpath(f'/html/body/section[2]/div/div[4]/div/div/div[{cont}]/div/div/div/h3')

                        #nome = elementos.text
                        #print(nome)

                        lista_links.append(link)
                        #lista_nomes.append(nome)

                        cont2+=1
                    except:
                        a=False
                        cont1+=1
                
                    
              
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links#, lista_nomes

# %%
invalidos = ["/", "|", "<", ">", "*", ":", "“", "?"]

# %%
from selenium.webdriver.chrome.options import Options
def baixar_contratos(numero_de_tentativas, css_code_selector, driver):
    
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    cont = 1
    roda = True
    
    # Criar pasta:
    os.chdir('./Bahia')
    
    nome = driver.find_element_by_xpath('/html/body/div[1]/div[3]/h1')
    nome = nome.text
    
    print(nome)
    nome_ant = nome
    for i in range(0,len(nome)):
        if nome[i] in invalidos:
            nome=nome.replace(nome[i], " ")

    
    os.mkdir(f'./{nome}') 
   
    
    os.chdir('..')
    
    
   
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
               /html/body/div[1]/div[4]/div[2]/div/div[2]/table/tbody/tr/td[1]
                

            driver.find_element_by_xpath(f'/html/body/section[2]/div/div/div[5]/div[1]/span').click()
            while roda == True:
                try:
                    print("entrei no try")
                    e = driver.find_element_by_xpath(f'/html/body/section[2]/div/div/div[5]/div[2]/div/table/tbody/tr[{cont}]/td/a')#.click()
                    link = e.get_attribute("href")
                    lista_links.append(link)
                    
                   
                    cont+=1
                except Exception as e:
                    print("parei")
                    roda = False
            print('aaa')
            print(lista_links)
            for l in lista_links:
                 
                #driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')
                print('a1')
                options = webdriver.ChromeOptions()
                
                options.add_experimental_option('excludeSwitches', ['enable-logging'])
                prefs = {"profile.default_content_settings.popups": 0,    
                        "download.default_directory":fr"C:\Users\Lais Nascimento\Desktop\Base_PPP\Untitled Folder\São_Paulo\{nome}", ### Set the path accordingly
                        "download.prompt_for_download": False, ## change the downpath accordingly
                        "download.directory_upgrade": True}
                options.add_experimental_option("prefs", prefs)
                
                print('a2')
               
                
                driver = webdriver.Chrome(executable_path=r'./chromedriver.exe', options=options)
                actionChains = ActionChains(driver)

                driver.get(l)
                
                actionChains.context_click(l).perform()
                    
                time.sleep(60)
   

                    
                driver.close()
                    
                    
      
              
            break
        
        #caso não funcione, aumenta a tentativa
        except Exception as e:
            print(e)
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lais Nascimento\\Desktop\\Base_PPP\\Untitled Folder'

# %%
n = 1
links = []

roda = True


while roda == True:
    url = "http://www.parcerias.sp.gov.br/Parcerias/Projetos/Portfolio"
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    lista_de_links = acha_lista_de_links(1000, "#ngo > div.view-content-wrap  > div", driver)

    print(lista_de_links)
   
        
    

    roda=False
    driver.close()
# Out:
# Pass tentativa!

# %%
n = 0
links = []

roda = True


# Cria pasta SP
#
os.mkdir('./São_Paulo')
#os.chdir('..')

while n<len(lista_de_links):
    url = lista_de_links[n]
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    baixar_contratos(2, "#ngo > div.view-content-wrap  > div", driver)

    time.sleep(10)
   
        
    

    n+=1
    driver.close()
# Out:
# Pass tentativa!
# Linha 05 Lilás e Linha 17 (Monotrilho) Ouro - Metrô
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29142', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=32021']
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# 05 Aeródromos Públicos - Aviação Executiva - (Jundiaí, Brangança Paulista, Campinas, Ubatuba e Itanhaém)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão de Rodovias (4a etapa - Centro Oeste Paulista e Rodovias Calçados)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# FURP – Planta de Produção Américo de Brasiliense
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2162']
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Sistema Produtor de São Lourenço
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Linha 6 - Laranja
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2211', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2213', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2214', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2215', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=23603', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=23604', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29184', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29842', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29931', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29932', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29974', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29975']
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Complexos Hospitalares
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2168', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2169', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2170', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2171', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2172', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2173', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2178', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2179', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2180', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2181', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2182', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2183', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2184']
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# SIM - Sistema Integrado Metropolitano da RMBS (modal VLT)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Linha 18 – Bronze (modal monotrilho)
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2206', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2207', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2208', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2209', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2210', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=26122', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29093', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29094', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29095', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29863']
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Rodovia Tamoios (3a etapa)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Habitação (1º Lote - Centro de SP)
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=2217']
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Linha 8 - Diamante
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Linha 4 - Amarela
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Sistema Produtor do Alto Tietê - ETA Taiaçupeba
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão do Serviço Rodoviário Intermunicipal de Transporte de Passageiros do Estado de São Paulo
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Centro de Exposição Imigrantes (CEI)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão RMSP Ônibus Metropolitano
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Linha 08 Diamante e Linha 09 Esmeralda de Trens metropolitanos
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=30357']
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Linha 15 Prata (monotrilho) - Metrô São Paulo
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão do Parque da Cantareira e do Parque Alberto Löfgren
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=33575']
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Concessões em Campos do Jordão
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29527', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29528', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=29529']
# a1
# a2
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# Trem Intercidades: Trecho São Paulo - Americana
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão dos Aeroportos Regionais e de Aviação Executiva do Governo do Estado de São Paulo
# entrei no try
# entrei no try
# entrei no try
# entrei no try
# parei
# aaa
# ['http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=33600', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=33601', 'http://www.parcerias.sp.gov.br/Parcerias/Documento/Download?codigo=33602']
# a1
# a2
# a1
# a2
# a1
# a2
# Pass acha_lista!
# Pass tentativa!
# PIPA - Piracicaba-Panorama
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão Complexo Constãncio Vaz Guimarães
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão do Zoológico e do Jardim Botânico de São Paulo
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão do Sistema de Travessias Litorâneas
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão de Rodovias - Lote Rodoanel Norte
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Caminhos do Mar
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Lote Litoral Paulista
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# PPP Educação - Novas Escolas
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Programa de PPP Prisionais – PPP Integral
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Programa de PPP Prisionais – PPP Com Ativos Existentes
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Parques Urbanos - Água Branca, Villa-Lobos e Cândido Portinari
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão Estrada de Ferro Campos do Jordão - EFCJ
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão de Rodovias (5ª Rodada) - Bloco Noroeste Paulista
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Casa das Retortas
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Ligação Planalto-Santos (Linha Verde)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Concessão do Transporte Intermunicipal de Passageiros da Região Metropolitana de Campinas (RMC)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Mosaico de Paranapiacaba - PETAR (Parque Estadual Turístico do Alto Ribeira)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Casarão Franco de Mello (Av. Paulista)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Serviços de Loterias do Estado de São Paulo
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# CITI II (Centro Internacional de Tecnologia e Inovação)
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas
# Pass tentativa!
# Usinas Solares - Geração de Energia Solar Fotovoltaica
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/section[2]/div/div/div[5]/div[1]/span"}
#   (Session info: chrome=105.0.5195.127)
#
# Número de tentativas excedidas

# %%
nome = "nomeeeeeeeee"

# %%
a =fr"C:\Users\Lais Nascimento\Desktop\Base_PPP\Untitled Folder\São_Paulo\{nome}"

# %%
print(a)
# Out:
# C:\Users\Lais Nascimento\Desktop\Base_PPP\Untitled Folder\São_Paulo\nomeeeeeeeee

# %%
os.mkdir('./Trem Intercidades Trecho São Paulo - Americana')
