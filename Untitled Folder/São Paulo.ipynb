# %%
from tkinter import *

from tkinter.ttk import *
import re
from textblob import TextBlob
from tqdm.auto import tqdm
from tkinter import Label
import time
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup

# %%
def tentativa(numero_de_tentativas, css_code_selector,driver):
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual <= numero_de_tentativas:
        
        #tenta clicar no botão
        try:
            driver.find_element_by_css_selector(css_code_selector).click()
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
    
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
        
    #caso contrário, informa que passou no teste
    else:
        print("Pass tentativa!")
    
    return

# %%
def acha_lista_de_links(numero_de_tentativas, css_code_selector, driver):
    
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    cont = 1
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
            
            while cont <=44:
            

                elementos = driver.find_element_by_xpath(f'/html/body/section[2]/div/div[4]/div/div/div[{cont}]/div/div/div/h3/a')


                link = elementos.get_attribute("href")
                lista_links.append(link)
                
                cont+=1
                
                    
              
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
def baixar_contratos(numero_de_tentativas, css_code_selector, driver):
    
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    cont = 1
    roda = True
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
               

            driver.find_element_by_xpath(f'/html/body/section[2]/div/div/div[5]/div[1]/span').click()
            while roda == True:
                try:
                    print("entrei no try")
                    e = driver.find_element_by_xpath(f'/html/body/section[2]/div/div/div[5]/div[2]/div/table/tbody/tr[{cont}]/td/a')#.click()
                    link = e.get_attribute("href")
                    lista_links.append(link)
                    
                   
                    cont+=1
                except Exception as e:
                    print("parei")
                    roda = False
            
            
            for l in lista_links:
                driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')
                driver.get(l)
                    
                time.sleep(40)
   

                    
                driver.close()
                    
                    
                
                    
       
                    
              
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
n = 1
links = []

roda = True

while roda == True:
    url = "http://www.parcerias.sp.gov.br/Parcerias/Projetos/Portfolio"
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    lista_de_links = acha_lista_de_links(1000, "#ngo > div.view-content-wrap  > div", driver)

    print(lista_de_links)
   
        
    

    roda=False
    driver.close()
# Out:
# Pass tentativa!
# Pass acha_lista!
# ['http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/109', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/112', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/113', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/114', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/115', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/116', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/117', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/118', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/119', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/120', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/121', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/122', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/123', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/124', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/126', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/127', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/128', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/129', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/131', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/132', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/133', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/136', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/139', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/145', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/146', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/147', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/148', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/149', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/150', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/152', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/153', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/154', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/155', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/156', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/157', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/158', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/159', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/160', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/161', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/162', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/163', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/164', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/165', 'http://www.parcerias.sp.gov.br/Parcerias/Projetos/Detalhes/166']

# %%
n = 0
links = []

roda = True

while n<len(lista_de_links):
    url = lista_de_links[n]
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    baixar_contratos(1000, "#ngo > div.view-content-wrap  > div", driver)

    time.sleep(10)
   
        
    

    n+=1
    driver.close()
# Out:
# Pass tentativa!
# entrei no try
# entrei no try
# entrei no try
# parei
# Pass acha_lista!
